# %% [markdown]
# <a href="https://colab.research.google.com/github/akashcode37/Akash37/blob/master/text_summarize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import bs4 as bs  
import urllib.request  
import re
import nltk
#nltk.download('punkt')
#nltk.download('stopwords')
scraped_data = urllib.request.urlopen('https://www.studypage.in/reading/my-vision-for-india-by-dr-a-p-j-abdul-kalam')  
article = scraped_data.read()

parsed_article = bs.BeautifulSoup(article,'lxml')

paragraphs = parsed_article.find_all('p')

article_text = ""

for p in paragraphs:  
    article_text += p.text

# %%
# Removing Square Brackets and Extra Spaces
article_text = re.sub(r'\[[0-9]*\]', ' ', article_text)  
article_text = re.sub(r'\s+', ' ', article_text)

# %%
# Removing special characters and digits
formatted_article_text = re.sub('[^a-zA-Z]', ' ', article_text )  
formatted_article_text = re.sub(r'\s+', ' ', formatted_article_text)

# %%
sentence_list = nltk.sent_tokenize(article_text)

# %%
#Find Weighted Frequency of Occurrence

stopwords = nltk.corpus.stopwords.words('english')

word_frequencies = {}  
for word in nltk.word_tokenize(formatted_article_text):  
    if word not in stopwords:
        if word not in word_frequencies.keys():
            word_frequencies[word] = 1
        else:
            word_frequencies[word] += 1

# %%
word_frequencies
# Out:
# {'A': 3,
#  'AMERICA': 1,
#  'AND': 2,
#  'ARE': 1,
#  'ASK': 1,
#  'Abdul': 2,
#  'Alexander': 1,
#  'America': 1,
#  'Americans': 1,
#  'BE': 1,
#  'Because': 2,
#  'Both': 1,
#  'Brahm': 1,
#  'British': 1,
#  'But': 1,
#  'CAN': 1,
#  'COUNTRIES': 1,
#  'DEVELOPMENT': 1,
#  'DO': 2,
#  'DONE': 1,
#  'Dear': 1,
#  'Dept': 1,
#  'Dhawan': 1,
#  'Dr': 5,
#  'Dutch': 1,
#  'European': 1,
#  'F': 1,
#  'FIRST': 1,
#  'FOR': 1,
#  'FREEDOM': 1,
#  'Finally': 1,
#  'First': 2,
#  'Following': 1,
#  'For': 2,
#  'French': 1,
#  'From': 1,
#  'GDP': 2,
#  'Greeks': 1,
#  'HAS': 1,
#  'Having': 1,
#  'He': 3,
#  'Hyderabad': 1,
#  'I': 9,
#  'INDIA': 2,
#  'If': 1,
#  'In': 1,
#  'Independence': 2,
#  'India': 20,
#  'Indians': 3,
#  'Instead': 1,
#  'Isn': 1,
#  'It': 2,
#  'J': 3,
#  'Kalam': 2,
#  'KalamI': 1,
#  'Kennedy': 1,
#  'MAKE': 1,
#  'MY': 1,
#  'Modern': 1,
#  'Moguls': 1,
#  'My': 2,
#  'OTHER': 1,
#  'Only': 1,
#  'Our': 2,
#  'P': 2,
#  'Portuguese': 1,
#  'Prakash': 1,
# ...

# %%
maximum_frequncy = max(word_frequencies.values())

for word in word_frequencies.keys():  
    word_frequencies[word] = (word_frequencies[word]/maximum_frequncy)

# %%
sentence_scores = {}  
for sent in sentence_list:  
    for word in nltk.word_tokenize(sent.lower()):
        if word in word_frequencies.keys():
            if len(sent.split(' ')) < 30:
                if sent not in sentence_scores.keys():
                    sentence_scores[sent] = word_frequencies[word]
                else:
                    sentence_scores[sent] += word_frequencies[word]

# %%
import heapq  
summary_sentences = heapq.nlargest(7, sentence_scores, key=sentence_scores.get)

summary = ' '.join(summary_sentences)  
print(summary)
# Out:
# You must proclaim India is not an underdeveloped nation; it is a highly developed nation.You say that our government is inefficient. Having subsequently achieved independence, we need to protect this freedom, without which no one will respect us.Second vision: India is growing economically and the rate of poverty is declining. In 3000 years of our history people from all over the world have come and invaded us, captured our lands, conquered our minds. He tries to make people realise their duties and motivate them to build a stronger India.First vision: He recalls how India has, time and again, been looted by invaders. You say that the phones don’t work, the railways are a joke, the airline is the worst in the world, and mails never reach their destination. You say, say and say. It is time we see ourselves as a developed nation.
